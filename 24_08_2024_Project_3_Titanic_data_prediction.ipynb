# %%
import seaborn as sns
import pandas as pd

titanic_data = sns.load_dataset('titanic')
titanic_data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Data investigation

# %%
titanic_data.isnull().sum() # checking null values
# Out:
# survived         0
# pclass           0
# sex            891
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who            891
# embark_town      0
# dtype: int64

# %%
titanic_data.dtypes
# Out:
# survived         int64
# pclass           int64
# sex            float64
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked         int64
# class           object
# who            float64
# embark_town      int64
# dtype: object

# %%
#titanic_data.drop('deck', axis=1, inplace=True) #a lot of empty values
titanic_data.drop(['alive', 'alone', 'adult_male'], axis=1, inplace=True)  # a lot of empty values
titanic_data.drop('class', axis=1, inplace=True) #a lot of empty values

# %% [markdown]
# ### Data transformation

# %%
titanic_data['class'] = titanic_data['class'].astype(str) # modified the object from category to str
titanic_data.fillna(0, inplace = True) #replace empty with null
titanic_data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-d2acd7dfacac> in <cell line: 2>()
#       1 titanic_data['class'] = titanic_data['class'].astype(str) # modified the object from category to str
# ----> 2 titanic_data.fillna(0, inplace = True) #replace empty with null
#       3 titanic_data.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    7295                     new_data = result._mgr
#    7296                 else:
# -> 7297                     new_data = self._mgr.fillna(
#    7298                         value=value, limit=limit, inplace=inplace, downcast=downcast
#    7299                     )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/base.py in fillna(self, value, limit, inplace, downcast)
#     171             limit = libalgos.validate_limit(None, limit=limit)
#     172
# --> 173         return self.apply_with_block(
#     174             "fillna",
#     175             value=value,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     352                 applied = b.apply(f, **kwargs)
#     353             else:
# --> 354                 applied = getattr(b, f)(**kwargs)
#     355             result_blocks = extend_blocks(applied, result_blocks)
#     356
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in fillna(self, value, limit, inplace, downcast, using_cow)
#    2006                 # 3rd party EA that has not implemented copy keyword yet
#    2007                 refs = None
# -> 2008                 new_values = self.values.fillna(value=value, method=None, limit=limit)
#    2009                 # issue the warning *after* retrying, in case the TypeError
#    2010                 #  was caused by an invalid fill_value
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/_mixins.py in fillna(self, value, method, limit, copy)
#     357                 else:
#     358                     new_values = self[:]
# --> 359                 new_values[mask] = value
#     360         else:
#     361             # We validate the fill_value even if there is nothing to fill
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/_mixins.py in __setitem__(self, key, value)
#     251     def __setitem__(self, key, value) -> None:
#     252         key = check_array_indexer(self, key)
# --> 253         value = self._validate_setitem_value(value)
#     254         self._ndarray[key] = value
#     255
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/categorical.py in _validate_setitem_value(self, value)
#    1560             return self._validate_listlike(value)
#    1561         else:
# -> 1562             return self._validate_scalar(value)
#    1563
#    1564     def _validate_scalar(self, fill_value):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/categorical.py in _validate_scalar(self, fill_value)
#    1585             fill_value = self._unbox_scalar(fill_value)
#    1586         else:
# -> 1587             raise TypeError(
#    1588                 "Cannot setitem on a Categorical with a new "
#    1589                 f"category ({fill_value}), set the categories first"
#
# TypeError: Cannot setitem on a Categorical with a new category (0), set the categories first

# %%
# sex column
sex_mapping = {'male': 0, 'female': 1}
titanic_data['sex'] = titanic_data['sex'].map(sex_mapping)
titanic_data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    0  22.0      1      0   7.2500        S  Third    man
# 1         1       1    1  38.0      1      0  71.2833        C  First  woman
# 2         1       3    1  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    1  35.0      1      0  53.1000        S  First  woman
# 4         0       3    0  35.0      0      0   8.0500        S  Third    man
#
#    embark_town
# 0  Southampton
# 1    Cherbourg
# 2  Southampton
# 3  Southampton
# 4  Southampton

# %%
# embarked town
titanic_data['embark_town'].unique()
embark_town_mapping = {'Southampton': 1, 'Cherbourg': 2, 'Queenstown': 3, 0:0 }
titanic_data['embark_town']= titanic_data['embark_town'].map(embark_town_mapping)
titanic_data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    0  22.0      1      0   7.2500        S  Third    man
# 1         1       1    1  38.0      1      0  71.2833        C  First  woman
# 2         1       3    1  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    1  35.0      1      0  53.1000        S  First  woman
# 4         0       3    0  35.0      0      0   8.0500        S  Third    man
#
#    embark_town
# 0          1.0
# 1          2.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
# embarked
titanic_data['embarked'].unique()
embarked_mapping = {'S': 1, 'C': 2, 'Q': 3, 0:0}
titanic_data['embarked'] = titanic_data['embarked'].map(embarked_mapping)
titanic_data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class    who  \
# 0         0       3    0  22.0      1      0   7.2500       1.0  Third    man
# 1         1       1    1  38.0      1      0  71.2833       2.0  First  woman
# 2         1       3    1  26.0      0      0   7.9250       1.0  Third  woman
# 3         1       1    1  35.0      1      0  53.1000       1.0  First  woman
# 4         0       3    0  35.0      0      0   8.0500       1.0  Third    man
#
#    embark_town
# 0          1.0
# 1          2.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
# who
titanic_data['who'].unique()
who_mapping = {'man': 0, 'woman': 1, 'child': 2}
titanic_data['who'] = titanic_data['who'].map(who_mapping)
titanic_data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class  who  \
# 0         0       3    0  22.0      1      0   7.2500       1.0  Third    0
# 1         1       1    1  38.0      1      0  71.2833       2.0  First    1
# 2         1       3    1  26.0      0      0   7.9250       1.0  Third    1
# 3         1       1    1  35.0      1      0  53.1000       1.0  First    1
# 4         0       3    0  35.0      0      0   8.0500       1.0  Third    0
#
#    embark_town
# 0          1.0
# 1          2.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    int64
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    float64
#  8   class        891 non-null    category
#  9   who          891 non-null    int64
#  10  embark_town  889 non-null    float64
# dtypes: category(1), float64(4), int64(6)
# memory usage: 70.7 KB
